# %% [markdown]
# <a href="https://colab.research.google.com/github/SkyHonor/Research-on-Deep-Learning-Algorithms/blob/main/AlexNet%20model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from PIL import Image, ImageFile
import torch.nn.functional as F

# %%
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, Dataset
import random
import numpy as np
import torch
from PIL import Image, ImageFile
import matplotlib.pyplot as plt

# !wget http://usrbb.ru/botainika/Pepper.zip
# !unzip Pepper.zip


transformation = transforms.Compose([transforms.Resize((256,256)),
                                     transforms.ToTensor()
                                    ])

data_path = datasets.ImageFolder(root="Pepper", transform = transformation)
batch_size = 16

train_dataloader = DataLoader(data_path,
                        shuffle=True,
                        num_workers=1,
                        batch_size=batch_size)
# Out:
# --2024-04-12 07:25:40--  http://usrbb.ru/botainika/Pepper.zip
# Resolving usrbb.ru (usrbb.ru)... 213.141.129.202
# Connecting to usrbb.ru (usrbb.ru)|213.141.129.202|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21077184 (20M) [application/zip]
# Saving to: ‘Pepper.zip’
#
# Pepper.zip          100%[===================>]  20.10M  2.32MB/s    in 10s
#
# 2024-04-12 07:25:51 (2.01 MB/s) - ‘Pepper.zip’ saved [21077184/21077184]
#
# Archive:  Pepper.zip
#    creating: Pepper/
#    creating: Pepper/Aphid/
#   inflating: Pepper/Aphid/10.jpg
#   inflating: Pepper/Aphid/11.jpg
#   inflating: Pepper/Aphid/12.jpg
#   inflating: Pepper/Aphid/17.jpg
#   inflating: Pepper/Aphid/2.jpg
#   inflating: Pepper/Aphid/23.jpg
#   inflating: Pepper/Aphid/3.jpg
#   inflating: Pepper/Aphid/6.jpg
#   inflating: Pepper/Aphid/9.jpg
#   inflating: Pepper/Aphid/a1.jpg
#   inflating: Pepper/Aphid/a13.jpg
#   inflating: Pepper/Aphid/a15.jpg
#   inflating: Pepper/Aphid/a16.jpg
#   inflating: Pepper/Aphid/a18.jpg
#   inflating: Pepper/Aphid/a19.jpg
#   inflating: Pepper/Aphid/a20.jpg
#   inflating: Pepper/Aphid/a21.jpg
#   inflating: Pepper/Aphid/a22.jpg
#   inflating: Pepper/Aphid/a4.jpg
#   inflating: Pepper/Aphid/a5.jpg
#   inflating: Pepper/Aphid/a7.jpg
#   inflating: Pepper/Aphid/a8.jpg
#   inflating: Pepper/Aphid/paph14.jpg
#    creating: Pepper/Bacterial spot/
#   inflating: Pepper/Bacterial spot/1.jpg
#   inflating: Pepper/Bacterial spot/10.jpg
#   inflating: Pepper/Bacterial spot/12.jpg
#   inflating: Pepper/Bacterial spot/13.jpg
#   inflating: Pepper/Bacterial spot/14.jpg
#   inflating: Pepper/Bacterial spot/16.jpg
#   inflating: Pepper/Bacterial spot/17.jpg
#   inflating: Pepper/Bacterial spot/19.jpg
#   inflating: Pepper/Bacterial spot/22.jpg
#   inflating: Pepper/Bacterial spot/23.jpg
#   inflating: Pepper/Bacterial spot/26.jpg
#   inflating: Pepper/Bacterial spot/3.jpg
#   inflating: Pepper/Bacterial spot/4.jpg
# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(data_path, test_size=0.2, random_state=0)

train_data_size = len(train)
test_data_size = len(test)

batch_size=8
train_data_loader = DataLoader(train, batch_size=batch_size)
test_data_loader = DataLoader(test, batch_size=batch_size)

# %%
model = models.alexnet(pretrained=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 149MB/s]

# %%
num_classes = len(data_path.classes)
model.classifier[6] = nn.Linear(4096, num_classes)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# %%
from torch import optim

net = model.cuda()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr = 0.0001 )

epochs = 30
counter = []
loss_history = []
iteration_number= 0

# %%
import matplotlib.pyplot as plt
for epoch in range(30):

    for i, (inputs, labels) in enumerate(train_dataloader, 0):

        inputs, labels = inputs.cuda(), labels.cuda()

        optimizer.zero_grad()

        outputs = net(inputs)

        loss = criterion(outputs, labels)

        loss.backward()

        optimizer.step()

        if i % 10 == 0 :
            print(f"Epoch number {epoch}\n Current loss {loss.item()}\n")
            iteration_number += 10

            counter.append(iteration_number)
            loss_history.append(loss.item())

plt.plot(counter, loss_history)
# Out:
# Epoch number 0
#  Current loss 2.5479137897491455
#
# Epoch number 0
#  Current loss 2.2260546684265137
#
# Epoch number 1
#  Current loss 1.4698742628097534
#
# Epoch number 1
#  Current loss 1.4143580198287964
#
# Epoch number 2
#  Current loss 1.1119617223739624
#
# Epoch number 2
#  Current loss 0.812761127948761
#
# Epoch number 3
#  Current loss 0.5234106183052063
#
# Epoch number 3
#  Current loss 0.4164157211780548
#
# Epoch number 4
#  Current loss 0.14010335505008698
#
# Epoch number 4
#  Current loss 0.20196285843849182
#
# Epoch number 5
#  Current loss 0.08267300575971603
#
# Epoch number 5
#  Current loss 0.23104818165302277
#
# Epoch number 6
#  Current loss 0.15386652946472168
#
# Epoch number 6
#  Current loss 0.032366782426834106
#
# Epoch number 7
#  Current loss 0.09029623121023178
#
# Epoch number 7
#  Current loss 0.011646823957562447
#
# Epoch number 8
#  Current loss 0.0896950513124466
#
# Epoch number 8
#  Current loss 0.02074018307030201
#
# Epoch number 9
#  Current loss 0.03756382316350937
#
# Epoch number 9
#  Current loss 0.024112163111567497
#
# Epoch number 10
#  Current loss 0.24285703897476196
#
# Epoch number 10
#  Current loss 0.06536448001861572
#
# Epoch number 11
#  Current loss 0.014766421169042587
#
# Epoch number 11
#  Current loss 0.0016341248992830515
#
# Epoch number 12
#  Current loss 0.0011251607211306691
#
# Epoch number 12
#  Current loss 0.013193412683904171
#
# Epoch number 13
#  Current loss 0.020514747127890587
#
# Epoch number 13
#  Current loss 0.001450314768590033
#
# Epoch number 14
#  Current loss 0.009611967951059341
#
# Epoch number 14
#  Current loss 0.014560656622052193
#
# Epoch number 15
#  Current loss 0.0016659073298797011
#
# Epoch number 15
#  Current loss 0.0009975022403523326
#
# Epoch number 16
#  Current loss 0.00013705457968171686
#
# Epoch number 16
#  Current loss 0.0006033940589986742
#
# Epoch number 17
#  Current loss 0.0005125910392962396
#
# Epoch number 17
#  Current loss 0.00016292375221382827
#
# Epoch number 18
#  Current loss 0.0001299866707995534
#
# Epoch number 18
#  Current loss 0.00040323453140445054
#
# Epoch number 19
#  Current loss 0.0002313414152013138
#
# Epoch number 19
#  Current loss 0.0001712481171125546
#
# Epoch number 20
#  Current loss 6.445528561016545e-05
#
# Epoch number 20
#  Current loss 0.00045709393452852964
#
# Epoch number 21
#  Current loss 4.784369593835436e-05
#
# Epoch number 21
#  Current loss 0.00011868953879456967
#
# Epoch number 22
#  Current loss 0.0002150145301129669
#
# Epoch number 22
#  Current loss 7.339140574913472e-05
#
# Epoch number 23
#  Current loss 6.645794201176614e-05
#
# Epoch number 23
#  Current loss 0.00021881118300370872
#
# Epoch number 24
#  Current loss 0.00020249452791176736
#
# Epoch number 24
#  Current loss 0.00015679177886340767
#
# Epoch number 25
#  Current loss 5.41383124073036e-05
#
# Epoch number 25
#  Current loss 0.00010419808677397668
#
# Epoch number 26
#  Current loss 0.00032637061667628586
#
# Epoch number 26
#  Current loss 0.00025749680935405195
#
# Epoch number 27
#  Current loss 2.3639828214072622e-05
#
# Epoch number 27
#  Current loss 5.9859765315195546e-05
#
# Epoch number 28
#  Current loss 0.00012744807463604957
#
# Epoch number 28
#  Current loss 5.649212107528001e-05
#
# Epoch number 29
#  Current loss 0.0001186417939607054
#
# Epoch number 29
#  Current loss 5.757377948611975e-05

# %%
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

loss_func = torch.nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

def train_and_validate(model, loss_criterion, optimizer, epochs=25):
    '''
    Function to train and validate
    Parameters
        :param model: Model to train and validate
        :param loss_criterion: Loss Criterion to minimize
        :param optimizer: Optimizer for computing gradients
        :param epochs: Number of epochs (default=25)

    Returns
        model: Trained Model with best validation accuracy
        history: (dict object): Having training loss, accuracy and validation loss, accuracy
    '''

    start = time.time()
    history = []
    best_loss = 100000.0
    best_epoch = None
    model = model.to(device)

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))

        # Set to training mode
        model.train()

        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0

        valid_loss = 0.0
        valid_acc = 0.0

        for i, (inputs, labels) in enumerate(train_data_loader):

            inputs = inputs.to(device)
            labels = labels.to(device)

            # Clean existing gradients
            optimizer.zero_grad()

            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)

            # Compute loss
            loss = loss_criterion(outputs, labels)

            # Backpropagate the gradients
            loss.backward()

            # Update the parameters
            optimizer.step()

            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)

            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))

            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))

            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)

            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))


        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(test_data_loader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)

                #print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
        if valid_loss < best_loss:
            best_loss = valid_loss
            best_epoch = epoch

        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_valid_loss = valid_loss/test_data_size
        avg_valid_acc = valid_acc/test_data_size

        history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])

        epoch_end = time.time()

        print("Epoch : {:03d}, Training: Loss - {:.4f}, Accuracy - {:.4f}%, \n\t\tValidation : Loss - {:.4f}, Accuracy - {:.4f}%, Time: {:.4f}s".format(epoch, avg_train_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, epoch_end-epoch_start))

        # Save if the model has best accuracy till now
        #torch.save(model, '_model_'+str(epoch)+'.pt')

    return model, history, best_epoch

# %%
import matplotlib.pyplot as plt
import numpy as np

num_epochs = 50
trained_model, history, best_epoch = train_and_validate(net, loss_func, optimizer, num_epochs)

#torch.save(history, '_history.pt')
history = np.array(history)
plt.plot(history[:,0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
plt.ylim(0,1)
plt.show()
plt.plot(history[:,2:4])
plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.ylim(0,1)
plt.show()
# Out:
# Epoch: 1/50
# Epoch : 000, Training: Loss - 5.5963, Accuracy - 16.3551%,
# 		Validation : Loss - 2.2981, Accuracy - 16.6667%, Time: 1.0635s
# Epoch: 2/50
# Epoch : 001, Training: Loss - 2.3053, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2710, Accuracy - 16.6667%, Time: 0.9371s
# Epoch: 3/50
# Epoch : 002, Training: Loss - 2.2770, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2754, Accuracy - 16.6667%, Time: 0.9287s
# Epoch: 4/50
# Epoch : 003, Training: Loss - 2.2772, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2723, Accuracy - 16.6667%, Time: 0.9294s
# Epoch: 5/50
# Epoch : 004, Training: Loss - 2.2737, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2750, Accuracy - 16.6667%, Time: 0.9419s
# Epoch: 6/50
# Epoch : 005, Training: Loss - 2.2743, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2735, Accuracy - 16.6667%, Time: 0.9560s
# Epoch: 7/50
# Epoch : 006, Training: Loss - 2.2762, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2740, Accuracy - 16.6667%, Time: 0.9504s
# Epoch: 8/50
# Epoch : 007, Training: Loss - 2.2724, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2735, Accuracy - 16.6667%, Time: 0.9690s
# Epoch: 9/50
# Epoch : 008, Training: Loss - 2.2717, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2741, Accuracy - 16.6667%, Time: 0.9557s
# Epoch: 10/50
# Epoch : 009, Training: Loss - 2.2725, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2734, Accuracy - 16.6667%, Time: 0.9476s
# Epoch: 11/50
# Epoch : 010, Training: Loss - 2.2702, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2735, Accuracy - 16.6667%, Time: 0.9478s
# Epoch: 12/50
# Epoch : 011, Training: Loss - 2.2724, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2712, Accuracy - 16.6667%, Time: 0.9276s
# Epoch: 13/50
# Epoch : 012, Training: Loss - 2.2663, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2725, Accuracy - 16.6667%, Time: 0.9271s
# Epoch: 14/50
# Epoch : 013, Training: Loss - 2.2714, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2726, Accuracy - 16.6667%, Time: 0.9320s
# Epoch: 15/50
# Epoch : 014, Training: Loss - 2.2685, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2738, Accuracy - 16.6667%, Time: 0.9398s
# Epoch: 16/50
# Epoch : 015, Training: Loss - 2.2700, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2707, Accuracy - 16.6667%, Time: 0.9387s
# Epoch: 17/50
# Epoch : 016, Training: Loss - 2.2718, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2725, Accuracy - 16.6667%, Time: 1.0645s
# Epoch: 18/50
# Epoch : 017, Training: Loss - 2.2667, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2736, Accuracy - 16.6667%, Time: 1.0623s
# Epoch: 19/50
# Epoch : 018, Training: Loss - 2.2734, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2718, Accuracy - 16.6667%, Time: 1.2748s
# Epoch: 20/50
# Epoch : 019, Training: Loss - 2.2662, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2705, Accuracy - 16.6667%, Time: 0.9548s
# Epoch: 21/50
# Epoch : 020, Training: Loss - 2.2703, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2721, Accuracy - 16.6667%, Time: 0.9633s
# Epoch: 22/50
# Epoch : 021, Training: Loss - 2.2693, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2722, Accuracy - 16.6667%, Time: 0.9664s
# Epoch: 23/50
# Epoch : 022, Training: Loss - 2.2685, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2709, Accuracy - 16.6667%, Time: 0.9505s
# Epoch: 24/50
# Epoch : 023, Training: Loss - 2.2699, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2707, Accuracy - 16.6667%, Time: 0.9620s
# Epoch: 25/50
# Epoch : 024, Training: Loss - 2.2680, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2732, Accuracy - 16.6667%, Time: 0.9368s
# Epoch: 26/50
# Epoch : 025, Training: Loss - 2.2694, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2720, Accuracy - 16.6667%, Time: 0.9340s
# Epoch: 27/50
# Epoch : 026, Training: Loss - 2.2733, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2722, Accuracy - 16.6667%, Time: 0.9333s
# Epoch: 28/50
# Epoch : 027, Training: Loss - 2.2660, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2723, Accuracy - 16.6667%, Time: 1.0479s
# Epoch: 29/50
# Epoch : 028, Training: Loss - 2.2634, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2749, Accuracy - 16.6667%, Time: 1.0513s
# Epoch: 30/50
# Epoch : 029, Training: Loss - 2.2709, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2713, Accuracy - 16.6667%, Time: 0.9434s
# Epoch: 31/50
# Epoch : 030, Training: Loss - 2.2669, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2743, Accuracy - 16.6667%, Time: 0.9455s
# Epoch: 32/50
# Epoch : 031, Training: Loss - 2.2700, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2729, Accuracy - 16.6667%, Time: 0.9416s
# Epoch: 33/50
# Epoch : 032, Training: Loss - 2.2703, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2718, Accuracy - 16.6667%, Time: 0.9475s
# Epoch: 34/50
# Epoch : 033, Training: Loss - 2.2665, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2737, Accuracy - 16.6667%, Time: 0.9519s
# Epoch: 35/50
# Epoch : 034, Training: Loss - 2.2697, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2737, Accuracy - 16.6667%, Time: 0.9473s
# Epoch: 36/50
# Epoch : 035, Training: Loss - 2.2691, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2718, Accuracy - 16.6667%, Time: 0.9327s
# Epoch: 37/50
# Epoch : 036, Training: Loss - 2.2720, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2716, Accuracy - 16.6667%, Time: 0.9413s
# Epoch: 38/50
# Epoch : 037, Training: Loss - 2.2720, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2717, Accuracy - 16.6667%, Time: 0.9472s
# Epoch: 39/50
# Epoch : 038, Training: Loss - 2.2706, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2734, Accuracy - 16.6667%, Time: 0.9336s
# Epoch: 40/50
# Epoch : 039, Training: Loss - 2.2669, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2730, Accuracy - 16.6667%, Time: 0.9420s
# Epoch: 41/50
# Epoch : 040, Training: Loss - 2.2664, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2752, Accuracy - 16.6667%, Time: 0.9407s
# Epoch: 42/50
# Epoch : 041, Training: Loss - 2.2660, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2721, Accuracy - 16.6667%, Time: 0.9432s
# Epoch: 43/50
# Epoch : 042, Training: Loss - 2.2672, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2722, Accuracy - 16.6667%, Time: 0.9519s
# Epoch: 44/50
# Epoch : 043, Training: Loss - 2.2684, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2726, Accuracy - 16.6667%, Time: 0.9381s
# Epoch: 45/50
# Epoch : 044, Training: Loss - 2.2672, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2734, Accuracy - 16.6667%, Time: 0.9391s
# Epoch: 46/50
# Epoch : 045, Training: Loss - 2.2695, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2721, Accuracy - 16.6667%, Time: 0.9506s
# Epoch: 47/50
# Epoch : 046, Training: Loss - 2.2672, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2726, Accuracy - 16.6667%, Time: 0.9582s
# Epoch: 48/50
# Epoch : 047, Training: Loss - 2.2685, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2728, Accuracy - 16.6667%, Time: 0.9605s
# Epoch: 49/50
# Epoch : 048, Training: Loss - 2.2668, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2720, Accuracy - 16.6667%, Time: 0.9470s
# Epoch: 50/50
# Epoch : 049, Training: Loss - 2.2687, Accuracy - 17.2897%,
# 		Validation : Loss - 2.2735, Accuracy - 16.6667%, Time: 0.9382s
